# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(f"{self.name}さん")
    print(f"{self.age}歳")

Taro = Human("太郎", 20)

Taro.printinfo()
# Out:
# 太郎さん
# 20歳
